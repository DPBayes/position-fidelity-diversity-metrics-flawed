# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Gaussian Mean Difference

# %%
pd.read_csv("../results/pass-fail-tables/gaussian-mean-difference.csv", index_col=[0, 1, 2])
# Out:
#                                  coverage  density  \
# dim desiderata criterion
# 1   bounds     identical             True     True
#                extreme negative      True     True
#                extreme positive      True     True
#     property   bell shape            True     True
# 8   bounds     identical             True     True
#                extreme negative      True     True
#                extreme positive      True     True
#     property   bell shape            True     True
# 64  bounds     identical             True     True
#                extreme negative      True     True
#                extreme positive      True     True
#     property   bell shape            True     True
#
#                                  integrated_alpha_precision  \
# dim desiderata criterion
# 1   bounds     identical                               True
#                extreme negative                        True
#                extreme positive                        True
# ...

# %% [markdown]
# # Gaussian Mean Difference with Outlier

# %%
pd.read_csv("../results/pass-fail-tables/gaussian-mean-difference-with-outlier.csv", index_col=[0, 1, 2, 3])
# Out:
#                                                   coverage  density  \
# outlier_scenario dim desiderata criterion
# real_outlier     1   bounds     identical             True     True
#                                 extreme negative      True     True
#                                 extreme positive      True    False
#                      property   bell shape            True     True
#                  8   bounds     identical             True     True
#                                 extreme negative      True     True
#                                 extreme positive      True    False
#                      property   bell shape            True     True
#                  64  bounds     identical             True     True
#                                 extreme negative      True     True
#                                 extreme positive      True    False
#                      property   bell shape            True     True
# ...

# %% [markdown]
# # Gaussian Std. Difference

# %%
pd.read_csv("../results/pass-fail-tables/gaussian-std-difference.csv", index_col=[0, 1, 2])
# Out:
#                               coverage  density  integrated_alpha_precision  \
# dim desiderata criterion
# 1   bounds     identical          True     True                        True
#                low syn. std.      True     True                       False
#                high syn. std.      low     True                        True
#     property   shape               low     True                       False
# 8   bounds     identical          True     True                        True
#                low syn. std.     False    False                       False
#                high syn. std.      low     True                        True
#     property   shape               low     True                       False
# 64  bounds     identical          True     True                       False
#                low syn. std.     False    False                       False
#                high syn. std.      low     True                        True
# ...

# %% [markdown]
# # Gaussian Mixture Simultaneous Mode Dropping

# %%
pd.read_csv("../results/pass-fail-tables/gaussian-mixture-simultaneous-mode-dropping.csv", index_col=[0, 1, 2])
# Out:
#                                    coverage  density  \
# dim desiderata criterion
# 1   bounds     identical               True     True
#                fully_dropped_modes      NaN     True
#     property   shape                   True     True
# 8   bounds     identical               True     True
#                fully_dropped_modes      NaN     True
#     property   shape                   True    False
# 64  bounds     identical               True     True
#                fully_dropped_modes      NaN     True
#     property   shape                   True     True
#
#                                     integrated_alpha_precision  \
# dim desiderata criterion
# 1   bounds     identical                                  True
#                fully_dropped_modes                       False
#     property   shape                                     False
# 8   bounds     identical                                  True
# ...

# %% [markdown]
# # Gaussian Mixture Simultaneous Mode Dropping

# %%
pd.read_csv("../results/pass-fail-tables/gaussian-mixture-sequential-mode-dropping.csv", index_col=[0, 1, 2])
# Out:
#                                    coverage  density  \
# dim desiderata criterion
# 1   bounds     identical               True     True
#                fully_dropped_modes      NaN     True
#     property   shape                   True     True
# 8   bounds     identical               True     True
#                fully_dropped_modes      NaN     True
#     property   shape                   True     True
# 64  bounds     identical               True     True
#                fully_dropped_modes      NaN     True
#     property   shape                   True     True
#
#                                     integrated_alpha_precision  \
# dim desiderata criterion
# 1   bounds     identical                                  True
#                fully_dropped_modes                       False
#     property   shape                                     False
# 8   bounds     identical                                  True
# ...

# %% [markdown]
# # Gaussian Mixture Mode Dropping Invention

# %%
pd.read_csv("../results/pass-fail-tables/gaussian-mixture-mode-dropping-invention.csv", index_col=[0, 1])
# Out:
#                                coverage density integrated_alpha_precision  \
# desiderata criterion
# bounds     identical               True    True                       True
#            most dropped modes       NaN    True                      False
#            most invented modes    False     NaN                        NaN
# property   shape                  False    True                      False
#
#                                integrated_beta_recall precision  \
# desiderata criterion
# bounds     identical                            False      True
#            most dropped modes                     NaN      True
#            most invented modes                  False       NaN
# property   shape                                False      True
#
#                                precision_cover probabilistic_precision  \
# desiderata criterion
# bounds     identical                      True                   False
# ...

# %% [markdown]
# # Uniform Hypersphere Surface

# %%
pd.read_csv("../results/pass-fail-tables/uniform-hypersphere-surface.csv", index_col=[0, 1, 2])
# Out:
#                                   coverage  density  \
# dim desiderata criterion
# 2   bounds     identical              True     True
#                small syn. radius      True     True
#                large syn. radius      True     True
#     property   shape                  True     True
# 16  bounds     identical              True     True
#                small syn. radius     False    False
#                large syn. radius      True     True
#     property   shape                  True    False
# 128 bounds     identical              True     True
#                small syn. radius     False    False
#                large syn. radius      True     True
#     property   shape                 False    False
#
#                                   integrated_alpha_precision  \
# dim desiderata criterion
# 2   bounds     identical                                True
#                small syn. radius                        True
# ...

# %% [markdown]
# # Uniform Hypercube Varying Dataset Size

# %%
pd.read_csv("../results/pass-fail-tables/uniform-hypercube-varying-size.csv", index_col=[0, 1, 2])
# Out:
#                                 coverage  density  integrated_alpha_precision  \
# dim desiderata      criterion
# 1   hyperparameters shape           True     True                        True
#     property        large size      True     True                       False
# 8   hyperparameters shape          False    False                        True
#     property        large size     False    False                       False
# 64  hyperparameters shape           True     True                       False
#     property        large size     False    False                       False
#
#                                 integrated_beta_recall  precision  \
# dim desiderata      criterion
# 1   hyperparameters shape                         True       True
#     property        large size                    True       True
# 8   hyperparameters shape                         True      False
#     property        large size                   False      False
# ...

# %% [markdown]
# # Uniform Hypercube Varying Syn. Dataset Size

# %%
pd.read_csv("../results/pass-fail-tables/uniform-hypercube-varying-syn-size.csv", index_col=[0, 1, 2])
# Out:
#                                      coverage  density  \
# dim desiderata      criterion
# 1   hyperparameters shape                True     True
#     property        large syn. size      True     True
# 8   hyperparameters shape               False     True
#     property        large syn. size     False    False
# 64  hyperparameters shape                True     True
#     property        large syn. size     False    False
#
#                                      integrated_alpha_precision  \
# dim desiderata      criterion
# 1   hyperparameters shape                                  True
#     property        large syn. size                       False
# 8   hyperparameters shape                                  True
#     property        large syn. size                       False
# 64  hyperparameters shape                                  True
#     property        large syn. size                       False
#
# ...

# %% [markdown]
# # Sphere vs. Torus

# %%
pd.read_csv("../results/pass-fail-tables/sphere-torus.csv", index_col=[0, 1, 2])
# Out:
#                                             coverage  density  \
# real_dist   desiderata criterion
# real_sphere property   shape                    True     True
#             bounds     right extreme value      True     True
# real_torus  property   shape                   False     True
#             bounds     right extreme value     False     True
#
#                                             integrated_alpha_precision  \
# real_dist   desiderata criterion
# real_sphere property   shape                                      True
#             bounds     right extreme value                       False
# real_torus  property   shape                                      True
#             bounds     right extreme value                        True
#
#                                             integrated_beta_recall  precision  \
# real_dist   desiderata criterion
# real_sphere property   shape                                  True       True
# ...

# %% [markdown]
# # One vs. Two Modes

# %%
pd.read_csv("../results/pass-fail-tables/one-vs-two-modes.csv", index_col=[0, 1, 2])
# Out:
#                          coverage  density  integrated_alpha_precision  \
# dim desiderata criterion
# 1   property   shape        False     True                        True
#     bounds     identical     True     True                        True
# 8   property   shape          low     True                        True
#     bounds     identical     True     True                        True
# 64  property   shape          low     True                        True
#     bounds     identical     True     True                       False
#
#                          integrated_beta_recall  precision  precision_cover  \
# dim desiderata criterion
# 1   property   shape                      False       True             True
#     bounds     identical                  False       True             True
# 8   property   shape                        low       True             True
#     bounds     identical                  False      False             True
# ...

# %% [markdown]
# # Gaussian Scaling One Dimension

# %%
pd.read_csv("../results/pass-fail-tables/gaussian-scaling-one-dimension.csv", index_col=[0, 1])
# Out:
#                                      coverage  density  \
# desiderata      criterion
# transformations shape                    True     True
# bounds          left extreme value       True     True
#                 right extreme value      True     True
#
#                                      integrated_alpha_precision  \
# desiderata      criterion
# transformations shape                                      True
# bounds          left extreme value                         True
#                 right extreme value                        True
#
#                                      integrated_beta_recall  precision  \
# desiderata      criterion
# transformations shape                                  True      False
# bounds          left extreme value                     True       True
#                 right extreme value                    True      False
#
#                                      precision_cover  probabilistic_precision  \
# desiderata      criterion
# ...

# %% [markdown]
# # Gaussian Mean Difference with Pareto

# %%
pd.read_csv("../results/pass-fail-tables/gaussian-mean-difference-with-pareto.csv", index_col=[0, 1])
# Out:
#                              coverage  density  integrated_alpha_precision  \
# desiderata criterion
# bounds     identical             True     True                        True
#            extreme negative      True     True                        True
#            extreme positive      True     True                        True
# property   bell shape            True     True                        True
#
#                              integrated_beta_recall  precision  \
# desiderata criterion
# bounds     identical                          False       True
#            extreme negative                    True       True
#            extreme positive                    True      False
# property   bell shape                          True       True
#
#                              precision_cover  probabilistic_precision  \
# desiderata criterion
# bounds     identical                    True                    False
# ...

# %% [markdown]
# # High-Dimensional Gaussian with One Disjoint Dimension

# %%
pd.read_csv("../results/pass-fail-tables/gaussian-high-dim-one-disjoint-dim.csv", index_col=[0, 1])
# Out:
#                                 coverage  density  integrated_alpha_precision  \
# desiderata criterion
# property   shape                   False    False                       False
# bounds     left extreme value       True     True                        True
#            right extreme value     False    False                        True
#
#                                 integrated_beta_recall  precision  \
# desiderata criterion
# property   shape                                 False      False
# bounds     left extreme value                     True       True
#            right extreme value                    True      False
#
#                                 precision_cover  probabilistic_precision  \
# desiderata criterion
# property   shape                          False                    False
# bounds     left extreme value              True                     True
#            right extreme value            False                    False
#
# ...

# %% [markdown]
# # Discrete Numerical vs. Continuous Numerical

# %%
pd.read_csv("../results/pass-fail-tables/discrete-numerical-vs-continuous-numerical.csv", index_col=[0, 1, 2])
# Out:
#                                                  coverage  density  \
# real_type       desiderata criterion
# real_continuous property   shape                    False    False
#                 bounds     coarse discretisation     True    False
#                            fine discretisation      False     True
# real_discrete   property   shape                    False    False
#                 bounds     coarse discretisation      low     True
#                            fine discretisation       high    False
#
#                                                   integrated_alpha_precision  \
# real_type       desiderata criterion
# real_continuous property   shape                                       False
#                 bounds     coarse discretisation                       False
#                            fine discretisation                          True
# real_discrete   property   shape                                       False
# ...

# %% [markdown]
# # Aggregated Results

# %%
pd.read_csv("../results/pass-fails.csv", index_col=[0, 1])
# Out:
#                                                              coverage  \
# sanity check                                desiderata
# gaussian-mean-difference                    bounds               True
#                                             property             True
# gaussian-mean-difference-with-outlier       bounds               True
#                                             property             True
# gaussian-std-difference                     bounds              False
#                                             property            False
# gaussian-mixture-simultaneous-mode-dropping bounds               True
#                                             property             True
# gaussian-mixture-sequential-mode-dropping   bounds               True
#                                             property             True
# gaussian-mixture-mode-dropping-invention    bounds              False
#                                             property            False
# ...

# %% [markdown]
# # Fidelity Metric Results

# %%
pd.read_csv("../results/fidelity-pass-fails.csv", index_col=[0, 1])
# Out:
#                                                              precision  \
# sanity check                                desiderata
# gaussian-mean-difference                    bounds               False
#                                             property              True
# gaussian-mean-difference-with-outlier       bounds               False
#                                             property             False
# gaussian-std-difference                     bounds               False
#                                             property              True
# gaussian-mixture-simultaneous-mode-dropping bounds               False
#                                             property              True
# gaussian-mixture-sequential-mode-dropping   bounds               False
#                                             property              True
# gaussian-mixture-mode-dropping-invention    bounds                True
# ...

# %% [markdown]
# # Diversity Metric Results

# %%
pd.read_csv("../results/diversity-pass-fails.csv", index_col=[0, 1])
# Out:
#                                                             recall  coverage  \
# sanity check                                desiderata
# gaussian-mean-difference                    bounds           False      True
#                                             property          True      True
# gaussian-mean-difference-with-outlier       bounds           False      True
#                                             property         False      True
# gaussian-std-difference                     bounds           False     False
#                                             property          high     False
# gaussian-mixture-simultaneous-mode-dropping bounds           False      True
#                                             property         False      True
# gaussian-mixture-sequential-mode-dropping   bounds           False      True
#                                             property          True      True
# ...
